# %% [markdown]
# <a href="https://colab.research.google.com/github/dyahajengp/Pemrograman-Python/blob/main/13_COST231_Dyah_Ajeng_Pramudhita_1101191092.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Dyah Ajeng Pramudhita | NIM : 1101191092 | Kelas : TT-43-G3

# %% [markdown]
# # Grafik 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
f=1800 #MHz
loc1='urban'
loc2='suburban'
loc3='open'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
LpUrban1=cos(f,loc1,tower,user,d)
LpUrban2=cos(f,loc2,tower,user,d)
LpUrban3=cos(f,loc3,tower,user,d)

# %%
d_sort=d[np.argsort(d)]
Urban_sort1=LpUrban1[np.argsort(d)]
Urban_sort2=LpUrban2[np.argsort(d)]
Urban_sort3=LpUrban3[np.argsort(d)]

# %%
print(d_sort)
# Out:
# [201 201 205 210 213 219 220 220 223 223 227 232 233 234 237 240 247 247
#  250 253 255 258 263 266 276 287 293 293 294 294 298 302 305 306 307 308
#  308 314 315 316 318 318 318 319 321 328 329 333 336 336 336 337 339 341
#  353 353 356 364 368 372 372 372 379 379 380 381 393 397 397 399 400 402
#  402 406 407 407 408 409 409 412 412 416 424 425 425 426 428 432 436 436
#  436 439 441 443 448 450 455 455 457 459 463 467 470 472 475 475 475 477
#  477 481 482 486 488 489 490 490 493 495 498 500 501 501 502 504 504 505
#  505 513 517 525 525 528 531 533 534 534 536 536 542 542 546 546 548 548
#  550 550 552 553 556 564 565 566 566 571 572 575 575 582 585 586 588 591
#  594 599 605 608 621 622 627 636 643 644 646 648 649 651 652 653 657 661
#  662 664 664 665 666 671 672 674 679 680 681 684 685 688 689 690 694 696
#  697 698]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort1,'r', label='Urban')
plt.plot(d_sort,Urban_sort2,'y', label='Suburban')
plt.plot(d_sort,Urban_sort3,'k', label='Open')
plt.legend()
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.title("Frekuensi 1800 Mhz")
plt.show()

# %% [markdown]
# # Grafik 2

# %%
f2=700 #MHz
f3=900 #MHz

# %%
Lpf=cos(f,loc1,tower,user,d)
Lpf2=cos(f2,loc1,tower,user,d)
Lpf3=cos(f3,loc1,tower,user,d)

# %%
d_sort=d[np.argsort(d)]
f_sort1=Lpf[np.argsort(d)]
f_sort2=Lpf2[np.argsort(d)]
f_sort3=Lpf3[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,f_sort2,'y', label='700 MHz')
plt.plot(d_sort,f_sort3,'k', label='900 MHz')
plt.plot(d_sort,f_sort1,'r', label='1800 MHz')
plt.legend()
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.title("Model Urban")
plt.show()
